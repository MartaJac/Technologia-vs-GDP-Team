# %%
import pandas as pd

# %%
df=pd.read_csv("lista.csv")
df.head(50)
# Out:
#                          Country ID_Country
# 0                    Afghanistan        AFG
# 1                        Albania        ALB
# 2                        Algeria        DZA
# 3                         Angola        AGO
# 4                      Argentina        ARG
# 5                        Armenia        ARM
# 6                      Australia        AUS
# 7                        Austria        AUT
# 8                     Azerbaijan        AZE
# 9                        Bahrain        BHR
# 10                    Bangladesh        BGD
# 11                       Belarus        BLR
# 12                       Belgium        BEL
# 13                         Benin        BEN
# 14                       Bolivia        BOL
# 15        Bosnia and Herzegovina        BIH
# 16                      Botswana        BWA
# 17                        Brazil        BRA
# 18                      Bulgaria        BGR
# 19                  Burkina Faso        BFA
# ...

# %%
df_c=pd.read_csv("countries-3.csv")
df_c.head(50)
# Out:
#    Continent                           Country ID_Country
# 0     Africa                           Algeria        DZA
# 1     Africa                             Egypt        EGY
# 2     Africa                             Libya        LBY
# 3     Africa                           Morocco        MAR
# 4     Africa                             Sudan        SDN
# 5     Africa                           Tunisia        TUN
# 6     Africa                    Western Sahara        ESH
# 7     Africa    British Indian Ocean Territory        IOT
# 8     Africa                           Burundi        BDI
# 9     Africa                           Comoros        COM
# 10    Africa                          Djibouti        DJI
# 11    Africa                           Eritrea        ERI
# 12    Africa                          Ethiopia        ETH
# 13    Africa       French Southern Territories        ATF
# 14    Africa                             Kenya        KEN
# ...

# %%
df_m=df.merge(right=df_c,how="left",right_on="ID_Country",left_on="ID_Country")

df_m = df_m.dropna(subset=['ID_Country'])

df_m.head(150)
# Out:
#                 Country_x ID_Country Continent             Country_y
# 0             Afghanistan        AFG      Asia           Afghanistan
# 1                 Albania        ALB    Europe               Albania
# 2                 Algeria        DZA    Africa               Algeria
# 3                  Angola        AGO    Africa                Angola
# 4               Argentina        ARG  Americas             Argentina
# ..                    ...        ...       ...                   ...
# 145                Turkey        TUR      Asia               Türkiye
# 146          Turkmenistan        TKM      Asia          Turkmenistan
# 147                Uganda        UGA    Africa                Uganda
# 148               Ukraine        UKR    Europe               Ukraine
# 149  United Arab Emirates        ARE      Asia  United Arab Emirates
#
# [150 rows x 4 columns]

# %%
##df_m=df.drop(columns=['Country_y'])
##df_m.head(150)
df_m=pd.read_csv("lista_m.csv",
                    header=0,
                    ##sep=",",
                    usecols=[2,0,1],
                    names=["Country","ID_Country","Continent"]
                  )
##df_csv.insert(0, 'Country_ID', range(1, len(df_csv) + 1))
df_m.head(15)
# Out:
#         Country ID_Country Continent
# 0   Afghanistan        AFG      Asia
# 1       Albania        ALB    Europe
# 2       Algeria        DZA    Africa
# 3        Angola        AGO    Africa
# 4     Argentina        ARG  Americas
# 5       Armenia        ARM      Asia
# 6     Australia        AUS   Oceania
# 7       Austria        AUT    Europe
# 8    Azerbaijan        AZE      Asia
# 9       Bahrain        BHR      Asia
# 10   Bangladesh        BGD      Asia
# 11      Belarus        BLR    Europe
# 12      Belgium        BEL    Europe
# 13        Benin        BEN    Africa
# 14      Bolivia        BOL  Americas

# %%
df_m.to_csv('countries_c.csv', index=False)

# %%
df.merge.head(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.merge.head(50)
#
# AttributeError: 'function' object has no attribute 'head'
